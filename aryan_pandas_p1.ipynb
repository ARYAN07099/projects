# %%
import pandas as pd
import numpy as np

# %%
dff=pd.read_csv(r"C:\Users\kchin\Downloads\archive (1)\food_ingredients_and_allergens.csv")

# %%
dff
# Out:
#             Food Product Main Ingredient Sweetener Fat/Oil       Seasoning  \
# 0         Almond Cookies         Almonds     Sugar  Butter           Flour
# 1         Almond Cookies         Almonds     Sugar  Butter           Flour
# 2    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 3    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 4         Cheddar Cheese          Cheese       NaN     NaN            Salt
# ..                   ...             ...       ...     ...             ...
# 394           Lemon Bars     Lemon juice     Sugar  Butter     Flour, eggs
# 395            Pecan Pie          Pecans     Sugar  Butter      Corn syrup
# 396       Zucchini Bread        Zucchini     Sugar  Butter  Cinnamon, nuts
# 397         Banana Bread         Bananas     Sugar  Butter  Cinnamon, nuts
# 398       Hawaiian Pizza     Pizza dough       NaN     NaN  Pineapple, ham
#
#                   Allergens Prediction
# ...

# %%
dff.tail()
# Out:
#        Food Product Main Ingredient Sweetener Fat/Oil       Seasoning  \
# 394      Lemon Bars     Lemon juice     Sugar  Butter     Flour, eggs
# 395       Pecan Pie          Pecans     Sugar  Butter      Corn syrup
# 396  Zucchini Bread        Zucchini     Sugar  Butter  Cinnamon, nuts
# 397    Banana Bread         Bananas     Sugar  Butter  Cinnamon, nuts
# 398  Hawaiian Pizza     Pizza dough       NaN     NaN  Pineapple, ham
#
#               Allergens Prediction
# 394  Wheat, Dairy, Eggs   Contains
# 395  Wheat, Dairy, Nuts   Contains
# 396  Wheat, Dairy, Nuts   Contains
# 397  Wheat, Dairy, Nuts   Contains
# 398  Wheat, Pork, Dairy   Contains

# %%
dff.tail(15)
# Out:
#                  Food Product Main Ingredient Sweetener  \
# 384               Pumpkin Pie         Pumpkin     Sugar
# 385         Blueberry Muffins           Flour     Sugar
# 386  Sausage and Pepper Pizza     Pizza dough       NaN
# 387           Beef Wellington            Beef       NaN
# 388                    Jalebi           Flour     Sugar
# 389               Butter Naan           Flour       NaN
# 390                  Tiramisu     Ladyfingers     Sugar
# 391            Chocolate Cake           Flour     Sugar
# 392   Chocolate Chip Pancakes           Flour     Sugar
# 393                Lemon Bars     Lemon juice     Sugar
# 394                Lemon Bars     Lemon juice     Sugar
# 395                 Pecan Pie          Pecans     Sugar
# 396            Zucchini Bread        Zucchini     Sugar
# 397              Banana Bread         Bananas     Sugar
# 398            Hawaiian Pizza     Pizza dough       NaN
#
# ...

# %%
dff.head()
# Out:
#           Food Product Main Ingredient Sweetener Fat/Oil Seasoning  \
# 0       Almond Cookies         Almonds     Sugar  Butter     Flour
# 1       Almond Cookies         Almonds     Sugar  Butter     Flour
# 2  Chicken Noodle Soup   Chicken broth       NaN     NaN      Salt
# 3  Chicken Noodle Soup   Chicken broth       NaN     NaN      Salt
# 4       Cheddar Cheese          Cheese       NaN     NaN      Salt
#
#                 Allergens Prediction
# 0   Almonds, Wheat, Dairy   Contains
# 1   Almonds, Wheat, Dairy   Contains
# 2  Chicken, Wheat, Celery   Contains
# 3  Chicken, Wheat, Celery   Contains
# 4                   Dairy   Contains

# %%
dff.shape
# Out:
# (399, 7)

# %%
dff.columns
# Out:
# Index(['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil', 'Seasoning',
#        'Allergens', 'Prediction'],
#       dtype='object')

# %%
dff.describe()
# Out:
#                 Food Product Main Ingredient Sweetener    Fat/Oil  Seasoning  \
# count                    399             399       119        341        379
# unique                   259             101         9         35        185
# top     Stuffed Bell Peppers         Chicken     Sugar  Olive oil  Soy sauce
# freq                       4              61        92         90         15
#
#        Allergens Prediction
# count        251        398
# unique        39          2
# top        Dairy   Contains
# freq          83        255

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Food Product     399 non-null    object
#  1   Main Ingredient  399 non-null    object
#  2   Sweetener        119 non-null    object
#  3   Fat/Oil          341 non-null    object
#  4   Seasoning        379 non-null    object
#  5   Allergens        251 non-null    object
#  6   Prediction       398 non-null    object
# dtypes: object(7)
# memory usage: 21.9+ KB

# %%
dff.dtypes
# Out:
# Food Product       object
# Main Ingredient    object
# Sweetener          object
# Fat/Oil            object
# Seasoning          object
# Allergens          object
# Prediction         object
# dtype: object

# %%
dff['Food Product']
# Out:
# 0           Almond Cookies
# 1           Almond Cookies
# 2      Chicken Noodle Soup
# 3      Chicken Noodle Soup
# 4           Cheddar Cheese
#               ...
# 394             Lemon Bars
# 395              Pecan Pie
# 396         Zucchini Bread
# 397           Banana Bread
# 398         Hawaiian Pizza
# Name: Food Product, Length: 399, dtype: object

# %%
dff['Food Product'].unique
# Out:
# <bound method Series.unique of 0           Almond Cookies
# 1           Almond Cookies
# 2      Chicken Noodle Soup
# 3      Chicken Noodle Soup
# 4           Cheddar Cheese
#               ...
# 394             Lemon Bars
# 395              Pecan Pie
# 396         Zucchini Bread
# 397           Banana Bread
# 398         Hawaiian Pizza
# Name: Food Product, Length: 399, dtype: object>

# %%
dff[['Food Product','Sweetener']]
# Out:
#             Food Product Sweetener
# 0         Almond Cookies     Sugar
# 1         Almond Cookies     Sugar
# 2    Chicken Noodle Soup       NaN
# 3    Chicken Noodle Soup       NaN
# 4         Cheddar Cheese       NaN
# ..                   ...       ...
# 394           Lemon Bars     Sugar
# 395            Pecan Pie     Sugar
# 396       Zucchini Bread     Sugar
# 397         Banana Bread     Sugar
# 398       Hawaiian Pizza       NaN
#
# [399 rows x 2 columns]

# %%
dff
# Out:
#             Food Product Main Ingredient Sweetener Fat/Oil       Seasoning  \
# 0         Almond Cookies         Almonds     Sugar  Butter           Flour
# 1         Almond Cookies         Almonds     Sugar  Butter           Flour
# 2    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 3    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 4         Cheddar Cheese          Cheese       NaN     NaN            Salt
# ..                   ...             ...       ...     ...             ...
# 394           Lemon Bars     Lemon juice     Sugar  Butter     Flour, eggs
# 395            Pecan Pie          Pecans     Sugar  Butter      Corn syrup
# 396       Zucchini Bread        Zucchini     Sugar  Butter  Cinnamon, nuts
# 397         Banana Bread         Bananas     Sugar  Butter  Cinnamon, nuts
# 398       Hawaiian Pizza     Pizza dough       NaN     NaN  Pineapple, ham
#
#                   Allergens Prediction
# ...

# %%
dff.isnull()
# Out:
#      Food Product  Main Ingredient  Sweetener  Fat/Oil  Seasoning  Allergens  \
# 0           False            False      False    False      False      False
# 1           False            False      False    False      False      False
# 2           False            False       True     True      False      False
# 3           False            False       True     True      False      False
# 4           False            False       True     True      False      False
# ..            ...              ...        ...      ...        ...        ...
# 394         False            False      False    False      False      False
# 395         False            False      False    False      False      False
# 396         False            False      False    False      False      False
# 397         False            False      False    False      False      False
# 398         False            False       True     True      False      False
#
#      Prediction
# 0         False
# ...

# %%
dff.isnull().sum()
# Out:
# Food Product         0
# Main Ingredient      0
# Sweetener          280
# Fat/Oil             58
# Seasoning           20
# Allergens          148
# Prediction           1
# dtype: int64

# %%
dff[dff['Main Ingredient']=='Cheese']
# Out:
#         Food Product Main Ingredient Sweetener Fat/Oil            Seasoning  \
# 4     Cheddar Cheese          Cheese       NaN     NaN                 Salt
# 10      Cheese Pizza          Cheese       NaN     NaN         Tomato sauce
# 11  Margherita Pizza          Cheese       NaN     NaN  Tomato sauce, basil
#
#    Allergens Prediction
# 4      Dairy   Contains
# 10     Dairy   Contains
# 11     Dairy   Contains

# %%
dff.select_dtypes(include='object')
# Out:
#             Food Product Main Ingredient Sweetener Fat/Oil       Seasoning  \
# 0         Almond Cookies         Almonds     Sugar  Butter           Flour
# 1         Almond Cookies         Almonds     Sugar  Butter           Flour
# 2    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 3    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 4         Cheddar Cheese          Cheese       NaN     NaN            Salt
# ..                   ...             ...       ...     ...             ...
# 394           Lemon Bars     Lemon juice     Sugar  Butter     Flour, eggs
# 395            Pecan Pie          Pecans     Sugar  Butter      Corn syrup
# 396       Zucchini Bread        Zucchini     Sugar  Butter  Cinnamon, nuts
# 397         Banana Bread         Bananas     Sugar  Butter  Cinnamon, nuts
# 398       Hawaiian Pizza     Pizza dough       NaN     NaN  Pineapple, ham
#
#                   Allergens Prediction
# ...

# %%
dff.drop_duplicates()
# Out:
#             Food Product Main Ingredient Sweetener        Fat/Oil  \
# 0         Almond Cookies         Almonds     Sugar         Butter
# 2    Chicken Noodle Soup   Chicken broth       NaN            NaN
# 4         Cheddar Cheese          Cheese       NaN            NaN
# 5         Ranch Dressing      Buttermilk     Sugar  Vegetable oil
# 6        Caramel Popcorn         Popcorn     Sugar         Butter
# ..                   ...             ...       ...            ...
# 393           Lemon Bars     Lemon juice     Sugar         Butter
# 395            Pecan Pie          Pecans     Sugar         Butter
# 396       Zucchini Bread        Zucchini     Sugar         Butter
# 397         Banana Bread         Bananas     Sugar         Butter
# 398       Hawaiian Pizza     Pizza dough       NaN            NaN
#
#           Seasoning               Allergens Prediction
# 0             Flour   Almonds, Wheat, Dairy   Contains
# 2              Salt  Chicken, Wheat, Celery   Contains
# ...

# %%
dff.shape
# Out:
# (399, 7)

# %%
dff.drop_duplicates().shape
# Out:
# (309, 7)

# %%
dff.drop(['Seasoning'],axis=1)
# Out:
#             Food Product Main Ingredient Sweetener Fat/Oil  \
# 0         Almond Cookies         Almonds     Sugar  Butter
# 1         Almond Cookies         Almonds     Sugar  Butter
# 2    Chicken Noodle Soup   Chicken broth       NaN     NaN
# 3    Chicken Noodle Soup   Chicken broth       NaN     NaN
# 4         Cheddar Cheese          Cheese       NaN     NaN
# ..                   ...             ...       ...     ...
# 394           Lemon Bars     Lemon juice     Sugar  Butter
# 395            Pecan Pie          Pecans     Sugar  Butter
# 396       Zucchini Bread        Zucchini     Sugar  Butter
# 397         Banana Bread         Bananas     Sugar  Butter
# 398       Hawaiian Pizza     Pizza dough       NaN     NaN
#
#                   Allergens Prediction
# 0     Almonds, Wheat, Dairy   Contains
# 1     Almonds, Wheat, Dairy   Contains
# 2    Chicken, Wheat, Celery   Contains
# 3    Chicken, Wheat, Celery   Contains
# 4                     Dairy   Contains
# ...

# %%
dff.drop(dff.columns[[1,2,3]],axis=1)
# Out:
#             Food Product       Seasoning               Allergens Prediction
# 0         Almond Cookies           Flour   Almonds, Wheat, Dairy   Contains
# 1         Almond Cookies           Flour   Almonds, Wheat, Dairy   Contains
# 2    Chicken Noodle Soup            Salt  Chicken, Wheat, Celery   Contains
# 3    Chicken Noodle Soup            Salt  Chicken, Wheat, Celery   Contains
# 4         Cheddar Cheese            Salt                   Dairy   Contains
# ..                   ...             ...                     ...        ...
# 394           Lemon Bars     Flour, eggs      Wheat, Dairy, Eggs   Contains
# 395            Pecan Pie      Corn syrup      Wheat, Dairy, Nuts   Contains
# 396       Zucchini Bread  Cinnamon, nuts      Wheat, Dairy, Nuts   Contains
# 397         Banana Bread  Cinnamon, nuts      Wheat, Dairy, Nuts   Contains
# 398       Hawaiian Pizza  Pineapple, ham      Wheat, Pork, Dairy   Contains
#
# [399 rows x 4 columns]

# %%
dff["Seasoning"].fillna('Pepper')
# Out:
# 0               Flour
# 1               Flour
# 2                Salt
# 3                Salt
# 4                Salt
#             ...
# 394       Flour, eggs
# 395        Corn syrup
# 396    Cinnamon, nuts
# 397    Cinnamon, nuts
# 398    Pineapple, ham
# Name: Seasoning, Length: 399, dtype: object

# %%
dff
# Out:
#             Food Product Main Ingredient Sweetener Fat/Oil       Seasoning  \
# 0         Almond Cookies         Almonds     Sugar  Butter           Flour
# 1         Almond Cookies         Almonds     Sugar  Butter           Flour
# 2    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 3    Chicken Noodle Soup   Chicken broth       NaN     NaN            Salt
# 4         Cheddar Cheese          Cheese       NaN     NaN            Salt
# ..                   ...             ...       ...     ...             ...
# 394           Lemon Bars     Lemon juice     Sugar  Butter     Flour, eggs
# 395            Pecan Pie          Pecans     Sugar  Butter      Corn syrup
# 396       Zucchini Bread        Zucchini     Sugar  Butter  Cinnamon, nuts
# 397         Banana Bread         Bananas     Sugar  Butter  Cinnamon, nuts
# 398       Hawaiian Pizza     Pizza dough       NaN     NaN  Pineapple, ham
#
#                   Allergens Prediction
# ...
